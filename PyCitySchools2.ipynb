# %%
import pandas as pd
import numpy as np
import csv

# %%
#CSV file paths
schools_csv = "/users/rebeccatast/desktop/Pandas-Challenge/Resources/PyCitySchools.csv"
students_csv = "/users/rebeccatast/desktop/Pandas-Challenge/Resources/PyCityStudents.csv"

# %%
#Set dataframes
schools_df = pd.read_csv(schools_csv)
students_df = pd.read_csv(students_csv)

# %%
#Print first lines of Schools Dataset
schools_df.head()
# Out:
#    School ID            school_name      type  size   budget
# 0          0      Huang High School  District  2917  1910635
# 1          1   Figueroa High School  District  2949  1884411
# 2          2    Shelton High School   Charter  1761  1056600
# 3          3  Hernandez High School  District  4635  3022020
# 4          4    Griffin High School   Charter  1468   917500

# %%
#Print first lines of Students Dataset
students_df.head()
# Out:
#    Student ID       student_name gender grade        school_name  \
# 0           0       Paul Bradley      M   9th  Huang High School
# 1           1       Victor Smith      M  12th  Huang High School
# 2           2    Kevin Rodriguez      M  12th  Huang High School
# 3           3  Dr. Richard Scott      M  12th  Huang High School
# 4           4         Bonnie Ray      F   9th  Huang High School
#
#    reading_score  math_score
# 0             66          79
# 1             94          61
# 2             90          60
# 3             67          58
# 4             97          84

# %%
#Merge datasets and print
complete_data_df = pd.merge(schools_df, students_df,how = 'left', on=["school_name","school_name"])
print (complete_data_df)
complete_data_df.head()
# Out:
#        School ID         school_name      type  size   budget  Student ID  \
# 0              0   Huang High School  District  2917  1910635           0
# 1              0   Huang High School  District  2917  1910635           1
# 2              0   Huang High School  District  2917  1910635           2
# 3              0   Huang High School  District  2917  1910635           3
# 4              0   Huang High School  District  2917  1910635           4
# ...          ...                 ...       ...   ...      ...         ...
# 39165         14  Thomas High School   Charter  1635  1043130       39165
# 39166         14  Thomas High School   Charter  1635  1043130       39166
# 39167         14  Thomas High School   Charter  1635  1043130       39167
# 39168         14  Thomas High School   Charter  1635  1043130       39168
# 39169         14  Thomas High School   Charter  1635  1043130       39169
#
#             student_name gender grade  reading_score  math_score
# 0           Paul Bradley      M   9th             66          79
# 1           Victor Smith      M  12th             94          61
# 2        Kevin Rodriguez      M  12th             90          60
# 3      Dr. Richard Scott      M  12th             67          58
# 4             Bonnie Ray      F   9th             97          84
# ...                  ...    ...   ...            ...         ...
# 39165       Donna Howard      F  12th             99          90
# 39166          Dawn Bell      F  10th             95          70
# 39167     Rebecca Tanner      F   9th             73          84
# 39168       Desiree Kidd      F  10th             99          90
# 39169    Carolyn Jackson      F  11th             95          75
#
# [39170 rows x 11 columns]
#    School ID        school_name      type  size   budget  Student ID  \
# 0          0  Huang High School  District  2917  1910635           0
# 1          0  Huang High School  District  2917  1910635           1
# 2          0  Huang High School  District  2917  1910635           2
# 3          0  Huang High School  District  2917  1910635           3
# 4          0  Huang High School  District  2917  1910635           4
#
#         student_name gender grade  reading_score  math_score
# 0       Paul Bradley      M   9th             66          79
# 1       Victor Smith      M  12th             94          61
# 2    Kevin Rodriguez      M  12th             90          60
# 3  Dr. Richard Scott      M  12th             67          58
# 4         Bonnie Ray      F   9th             97          84

# %%
#Calculate total students, total schools, total budget
total_schools = len(complete_data_df["School ID"].unique())
print(total_schools)
total_students = complete_data_df["Student ID"].count()
print(total_students)
total_budget = sum(complete_data_df ["budget"].unique())
print(total_budget)
# Out:
# 15
# 39170
# 24649428

# %%
#Calculate Average Math and Reading Scores
avg_math = complete_data_df["math_score"].mean()
print(avg_math)
avg_reading = complete_data_df ["reading_score"].mean()
print(avg_reading)
# Out:
# 78.98537145774827
# 81.87784018381414

# %%
#Calculate percentage of students passing math
passing_math = complete_data_df.loc[students_df["math_score"] >= 70] ["math_score"].count()
print(passing_math)
percent_pass_math = passing_math/(total_students) *100
print(percent_pass_math)
# Out:
# 29370
# 74.9808526933878

# %%
#Calculate percentage of students passing reading
passing_reading = complete_data_df.loc[students_df["reading_score"] >= 70] ["reading_score"].count()
print(passing_reading)
percent_pass_reading = passing_reading/(total_students) *100
print(percent_pass_reading)
# Out:
# 33610
# 85.80546336482001

# %%
#Calculate total that passed math and reading
total_pass_rate = students_df[(students_df["math_score"] >= 70) & (students_df["reading_score"] >= 70)]["student_name"].count()/float(total_students)*100
print(total_pass_rate)
# Out:
# 65.17232575950983

# %%
#District Summary Dataframe
district_summary = pd.DataFrame({"Total Schools": [total_schools],
                           "Total Students": [total_students],
                           "Total Budget": [total_budget],
                           "Average Math Score": [avg_math],
                           "Average Reading Score": [avg_reading],
                           "% Students Passing Math":[percent_pass_math],
                           "% Students Passing Reading": [percent_pass_reading],
                           "% Students Passing Overall": [total_pass_rate]})



district_summary["Total Students"] = district_summary["Total Students"].map("{:,}".format)
district_summary["Total Budget"] = district_summary["Total Budget"].map("${:,.2f}".format)
district_summary["Average Math Score"] = district_summary["Average Math Score"].map("{:.2f}".format)
district_summary["Average Reading Score"] = district_summary["Average Reading Score"].map("{:.2f}".format)
district_summary["% Students Passing Math"] = district_summary["% Students Passing Math"].map("{:.2f}%".format)
district_summary["% Students Passing Reading"] = district_summary["% Students Passing Reading"].map("{:.2f}%".format)
district_summary["% Students Passing Overall"] = district_summary["% Students Passing Overall"].map("{:.2f}%".format)

district_summary
# Out:
#    Total Schools Total Students    Total Budget Average Math Score  \
# 0             15         39,170  $24,649,428.00              78.99
#
#   Average Reading Score % Students Passing Math % Students Passing Reading  \
# 0                 81.88                  74.98%                     85.81%
#
#   % Students Passing Overall
# 0                     65.17%

# %%
complete_data_df.head()
# Out:
#    School ID        school_name      type  size   budget  Student ID  \
# 0          0  Huang High School  District  2917  1910635           0
# 1          0  Huang High School  District  2917  1910635           1
# 2          0  Huang High School  District  2917  1910635           2
# 3          0  Huang High School  District  2917  1910635           3
# 4          0  Huang High School  District  2917  1910635           4
#
#         student_name gender grade  reading_score  math_score
# 0       Paul Bradley      M   9th             66          79
# 1       Victor Smith      M  12th             94          61
# 2    Kevin Rodriguez      M  12th             90          60
# 3  Dr. Richard Scott      M  12th             67          58
# 4         Bonnie Ray      F   9th             97          84

# %%
#Group by school
school_group_df = complete_data_df.set_index("school_name").groupby(["school_name"])
print(school_group)
school_group.head(15)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-962e2d829c89> in <module>
#       1 #Group by school
#       2 school_group_df = complete_data_df.set_index("school_name").groupby(["school_name"])
# ----> 3 print(school_group)
#       4 school_group.head(15)
#
# NameError: name 'school_group' is not defined

# %%
#School Types
school_types = schools_df.set_index("school_name")["type"]
#print(school_types)

# %%
#Total Students
students_per_school = school_group_df["Student ID"].count()
#print(students_per_school)

# %%
#Total School Budget
school_budget = schools_df.set_index("school_name")["budget"]
print(school_budget)
# Out:
# school_name
# Huang High School        1910635
# Figueroa High School     1884411
# Shelton High School      1056600
# Hernandez High School    3022020
# Griffin High School       917500
# Wilson High School       1319574
# Cabrera High School      1081356
# Bailey High School       3124928
# Holden High School        248087
# Pena High School          585858
# Wright High School       1049400
# Rodriguez High School    2547363
# Johnson High School      3094650
# Ford High School         1763916
# Thomas High School       1043130
# Name: budget, dtype: int64

# %%
#Per Student Budget
per_student_budget = school_budget/students_per_school
print(per_student_budget)
# Out:
# school_name
# Bailey High School       628.0
# Cabrera High School      582.0
# Figueroa High School     639.0
# Ford High School         644.0
# Griffin High School      625.0
# Hernandez High School    652.0
# Holden High School       581.0
# Huang High School        655.0
# Johnson High School      650.0
# Pena High School         609.0
# Rodriguez High School    637.0
# Shelton High School      600.0
# Thomas High School       638.0
# Wilson High School       578.0
# Wright High School       583.0
# dtype: float64

# %%
#Average Math Score
avg_math_score = school_group_df["math_score"].mean()
print(avg_math_score)
# Out:
# school_name
# Bailey High School       77.048432
# Cabrera High School      83.061895
# Figueroa High School     76.711767
# Ford High School         77.102592
# Griffin High School      83.351499
# Hernandez High School    77.289752
# Holden High School       83.803279
# Huang High School        76.629414
# Johnson High School      77.072464
# Pena High School         83.839917
# Rodriguez High School    76.842711
# Shelton High School      83.359455
# Thomas High School       83.418349
# Wilson High School       83.274201
# Wright High School       83.682222
# Name: math_score, dtype: float64

# %%
#Average Reading Score
avg_reading_score = school_group_df["reading_score"].mean()
print(avg_reading_score)
# Out:
# school_name
# Bailey High School       81.033963
# Cabrera High School      83.975780
# Figueroa High School     81.158020
# Ford High School         80.746258
# Griffin High School      83.816757
# Hernandez High School    80.934412
# Holden High School       83.814988
# Huang High School        81.182722
# Johnson High School      80.966394
# Pena High School         84.044699
# Rodriguez High School    80.744686
# Shelton High School      83.725724
# Thomas High School       83.848930
# Wilson High School       83.989488
# Wright High School       83.955000
# Name: reading_score, dtype: float64

# %%
#Percent Passing Math
pass_math = complete_data_df[complete_data_df["math_score"] >= 70].groupby("school_name")["Student ID"].count()
print(pass_math)
pass_math_percent = pass_math/ students_per_school * 100
print(pass_math_percent)
# Out:
# school_name
# Bailey High School       3318
# Cabrera High School      1749
# Figueroa High School     1946
# Ford High School         1871
# Griffin High School      1371
# Hernandez High School    3094
# Holden High School        395
# Huang High School        1916
# Johnson High School      3145
# Pena High School          910
# Rodriguez High School    2654
# Shelton High School      1653
# Thomas High School       1525
# Wilson High School       2143
# Wright High School       1680
# Name: Student ID, dtype: int64
# school_name
# Bailey High School       66.680064
# Cabrera High School      94.133477
# Figueroa High School     65.988471
# Ford High School         68.309602
# Griffin High School      93.392371
# Hernandez High School    66.752967
# Holden High School       92.505855
# Huang High School        65.683922
# Johnson High School      66.057551
# Pena High School         94.594595
# Rodriguez High School    66.366592
# Shelton High School      93.867121
# Thomas High School       93.272171
# Wilson High School       93.867718
# Wright High School       93.333333
# Name: Student ID, dtype: float64

# %%
#Percent Passing Reading
pass_reading = complete_data_df[complete_data_df["reading_score"] >= 70].groupby("school_name")["Student ID"].count()
print(pass_reading)
pass_reading_percent = pass_reading/students_per_school * 100
print(pass_reading_percent)
# Out:
# school_name
# Bailey High School       4077
# Cabrera High School      1803
# Figueroa High School     2381
# Ford High School         2172
# Griffin High School      1426
# Hernandez High School    3748
# Holden High School        411
# Huang High School        2372
# Johnson High School      3867
# Pena High School          923
# Rodriguez High School    3208
# Shelton High School      1688
# Thomas High School       1591
# Wilson High School       2204
# Wright High School       1739
# Name: Student ID, dtype: int64
# school_name
# Bailey High School       81.933280
# Cabrera High School      97.039828
# Figueroa High School     80.739234
# Ford High School         79.299014
# Griffin High School      97.138965
# Hernandez High School    80.862999
# Holden High School       96.252927
# Huang High School        81.316421
# Johnson High School      81.222432
# Pena High School         95.945946
# Rodriguez High School    80.220055
# Shelton High School      95.854628
# Thomas High School       97.308869
# Wilson High School       96.539641
# Wright High School       96.611111
# Name: Student ID, dtype: float64

# %%
#Percent Passing Math and Reading
school_pass_rate = complete_data_df[(complete_data_df["math_score"]>= 70) & (complete_data_df["reading_score"]>= 70)].groupby("school_name")["Student ID"].count()
print(school_pass_rate)
school_pass_percent = school_pass_rate/students_per_school*100
print(school_pass_percent)
# Out:
# school_name
# Bailey High School       2719
# Cabrera High School      1697
# Figueroa High School     1569
# Ford High School         1487
# Griffin High School      1330
# Hernandez High School    2481
# Holden High School        381
# Huang High School        1561
# Johnson High School      2549
# Pena High School          871
# Rodriguez High School    2119
# Shelton High School      1583
# Thomas High School       1487
# Wilson High School       2068
# Wright High School       1626
# Name: Student ID, dtype: int64
# school_name
# Bailey High School       54.642283
# Cabrera High School      91.334769
# Figueroa High School     53.204476
# Ford High School         54.289887
# Griffin High School      90.599455
# Hernandez High School    53.527508
# Holden High School       89.227166
# Huang High School        53.513884
# Johnson High School      53.539172
# Pena High School         90.540541
# Rodriguez High School    52.988247
# Shelton High School      89.892107
# Thomas High School       90.948012
# Wilson High School       90.582567
# Wright High School       90.333333
# Name: Student ID, dtype: float64

# %%
#Individual Schools Dataframe
school_group_df = pd.DataFrame ({"School Type": school_types,
                                "Total Students":students_per_school,
                                "Total School Budget":school_budget,
                                "Per Student Budget":per_student_budget,
                                "Average Math Score":avg_math_score,
                                "Average Reading Score":avg_reading_score,
                                "% Students Passing Math":pass_math_percent,
                                "% Students Passing Reading":pass_reading_percent,
                                "% Students Passing Overall": school_pass_percent})

school_group_df
# Out:
#                       School Type  Total Students  Total School Budget  \
# Bailey High School       District            4976              3124928
# Cabrera High School       Charter            1858              1081356
# Figueroa High School     District            2949              1884411
# Ford High School         District            2739              1763916
# Griffin High School       Charter            1468               917500
# Hernandez High School    District            4635              3022020
# Holden High School        Charter             427               248087
# Huang High School        District            2917              1910635
# Johnson High School      District            4761              3094650
# Pena High School          Charter             962               585858
# Rodriguez High School    District            3999              2547363
# Shelton High School       Charter            1761              1056600
# Thomas High School        Charter            1635              1043130
# Wilson High School        Charter            2283              1319574
# Wright High School        Charter            1800              1049400
#
#                        Per Student Budget  Average Math Score  \
# Bailey High School                  628.0           77.048432
# Cabrera High School                 582.0           83.061895
# Figueroa High School                639.0           76.711767
# Ford High School                    644.0           77.102592
# Griffin High School                 625.0           83.351499
# Hernandez High School               652.0           77.289752
# Holden High School                  581.0           83.803279
# Huang High School                   655.0           76.629414
# Johnson High School                 650.0           77.072464
# Pena High School                    609.0           83.839917
# Rodriguez High School               637.0           76.842711
# Shelton High School                 600.0           83.359455
# Thomas High School                  638.0           83.418349
# Wilson High School                  578.0           83.274201
# Wright High School                  583.0           83.682222
#
#                        Average Reading Score  % Students Passing Math  \
# Bailey High School                 81.033963                66.680064
# Cabrera High School                83.975780                94.133477
# Figueroa High School               81.158020                65.988471
# Ford High School                   80.746258                68.309602
# Griffin High School                83.816757                93.392371
# Hernandez High School              80.934412                66.752967
# Holden High School                 83.814988                92.505855
# Huang High School                  81.182722                65.683922
# Johnson High School                80.966394                66.057551
# Pena High School                   84.044699                94.594595
# Rodriguez High School              80.744686                66.366592
# Shelton High School                83.725724                93.867121
# Thomas High School                 83.848930                93.272171
# Wilson High School                 83.989488                93.867718
# Wright High School                 83.955000                93.333333
#
#                        % Students Passing Reading  % Students Passing Overall
# Bailey High School                      81.933280                   54.642283
# Cabrera High School                     97.039828                   91.334769
# Figueroa High School                    80.739234                   53.204476
# Ford High School                        79.299014                   54.289887
# Griffin High School                     97.138965                   90.599455
# Hernandez High School                   80.862999                   53.527508
# Holden High School                      96.252927                   89.227166
# Huang High School                       81.316421                   53.513884
# Johnson High School                     81.222432                   53.539172
# Pena High School                        95.945946                   90.540541
# Rodriguez High School                   80.220055                   52.988247
# Shelton High School                     95.854628                   89.892107
# Thomas High School                      97.308869                   90.948012
# Wilson High School                      96.539641                   90.582567
# Wright High School                      96.611111                   90.333333

# %%
#Sort Top 5 Schools
top_five = school_group_df.sort_values("% Students Passing Overall", ascending = False)
top_five.head()
# Out:
#                     School Type  Total Students  Total School Budget  \
# Cabrera High School     Charter            1858              1081356
# Thomas High School      Charter            1635              1043130
# Griffin High School     Charter            1468               917500
# Wilson High School      Charter            2283              1319574
# Pena High School        Charter             962               585858
#
#                      Per Student Budget  Average Math Score  \
# Cabrera High School               582.0           83.061895
# Thomas High School                638.0           83.418349
# Griffin High School               625.0           83.351499
# Wilson High School                578.0           83.274201
# Pena High School                  609.0           83.839917
#
#                      Average Reading Score  % Students Passing Math  \
# Cabrera High School              83.975780                94.133477
# Thomas High School               83.848930                93.272171
# Griffin High School              83.816757                93.392371
# Wilson High School               83.989488                93.867718
# Pena High School                 84.044699                94.594595
#
#                      % Students Passing Reading  % Students Passing Overall
# Cabrera High School                   97.039828                   91.334769
# Thomas High School                    97.308869                   90.948012
# Griffin High School                   97.138965                   90.599455
# Wilson High School                    96.539641                   90.582567
# Pena High School                      95.945946                   90.540541

# %%
#Sort Bottom 5 Schools
bottom_five = school_group_df.sort_values("% Students Passing Overall")
bottom_five.head()
# Out:
#                       School Type  Total Students  Total School Budget  \
# Rodriguez High School    District            3999              2547363
# Figueroa High School     District            2949              1884411
# Huang High School        District            2917              1910635
# Hernandez High School    District            4635              3022020
# Johnson High School      District            4761              3094650
#
#                        Per Student Budget  Average Math Score  \
# Rodriguez High School               637.0           76.842711
# Figueroa High School                639.0           76.711767
# Huang High School                   655.0           76.629414
# Hernandez High School               652.0           77.289752
# Johnson High School                 650.0           77.072464
#
#                        Average Reading Score  % Students Passing Math  \
# Rodriguez High School              80.744686                66.366592
# Figueroa High School               81.158020                65.988471
# Huang High School                  81.182722                65.683922
# Hernandez High School              80.934412                66.752967
# Johnson High School                80.966394                66.057551
#
#                        % Students Passing Reading  % Students Passing Overall
# Rodriguez High School                   80.220055                   52.988247
# Figueroa High School                    80.739234                   53.204476
# Huang High School                       81.316421                   53.513884
# Hernandez High School                   80.862999                   53.527508
# Johnson High School                     81.222432                   53.539172

# %%
#Math Scores by Grade
Ninth_graders = complete_data_df[(complete_data_df["grade"]=="9th")]
Tenth_graders = complete_data_df[(complete_data_df["grade"]=="10th")]
Eleven_graders = complete_data_df[(complete_data_df["grade"]=="11th")]
Tweleve_graders = complete_data_df[(complete_data_df["grade"]=="12th")]

# %%
Ninth_graders_schools = Ninth_graders.groupby(["school_name"]).mean()["math_score"]
Tenth_graders_schools = Tenth_graders.groupby(["school_name"]).mean()["math_score"]
Eleven_graders_schools = Eleven_graders.groupby(["school_name"]).mean()["math_score"]
Tweleve_graders_schools = Tweleve_graders.groupby(["school_name"]).mean()["math_score"]

# %%
math_scores_by_grade = pd.DataFrame({"9th": Ninth_graders_schools, "10th":Tenth_graders_schools, "11th":Eleven_graders_schools, "12th": Tweleve_graders_schools})
math_scores_by_grade = math_scores_by_grade[["9th", "10th", "11th", "12th"]]
math_scores_by_grade.index.name = None
math_scores_by_grade
# Out:
#                              9th       10th       11th       12th
# Bailey High School     77.083676  76.996772  77.515588  76.492218
# Cabrera High School    83.094697  83.154506  82.765560  83.277487
# Figueroa High School   76.403037  76.539974  76.884344  77.151369
# Ford High School       77.361345  77.672316  76.918058  76.179963
# Griffin High School    82.044010  84.229064  83.842105  83.356164
# Hernandez High School  77.438495  77.337408  77.136029  77.186567
# Holden High School     83.787402  83.429825  85.000000  82.855422
# Huang High School      77.027251  75.908735  76.446602  77.225641
# Johnson High School    77.187857  76.691117  77.491653  76.863248
# Pena High School       83.625455  83.372000  84.328125  84.121547
# Rodriguez High School  76.859966  76.612500  76.395626  77.690748
# Shelton High School    83.420755  82.917411  83.383495  83.778976
# Thomas High School     83.590022  83.087886  83.498795  83.497041
# Wilson High School     83.085578  83.724422  83.195326  83.035794
# Wright High School     83.264706  84.010288  83.836782  83.644986

# %%
#Reading Scores by Grade
Ninth_graders = complete_data_df[(complete_data_df["grade"]=="9th")]
Tenth_graders = complete_data_df[(complete_data_df["grade"]=="10th")]
Eleven_graders = complete_data_df[(complete_data_df["grade"]=="11th")]
Tweleve_graders = complete_data_df[(complete_data_df["grade"]=="12th")]

# %%
Ninth_graders_schools = Ninth_graders.groupby(["school_name"]).mean()["reading_score"]
Tenth_graders_schools = Tenth_graders.groupby(["school_name"]).mean()["reading_score"]
Eleven_graders_schools = Eleven_graders.groupby(["school_name"]).mean()["reading_score"]
Tweleve_graders_schools = Tweleve_graders.groupby(["school_name"]).mean()["reading_score"]

# %%
reading_scores_by_grade = pd.DataFrame({"9th": Ninth_graders_schools, "10th":Tenth_graders_schools, "11th":Eleven_graders_schools, "12th": Tweleve_graders_schools})
reading_scores_by_grade = reading_scores_by_grade[["9th", "10th", "11th", "12th"]]
reading_scores_by_grade.index.name = None
reading_scores_by_grade
# Out:
#                              9th       10th       11th       12th
# Bailey High School     81.303155  80.907183  80.945643  80.912451
# Cabrera High School    83.676136  84.253219  83.788382  84.287958
# Figueroa High School   81.198598  81.408912  80.640339  81.384863
# Ford High School       80.632653  81.262712  80.403642  80.662338
# Griffin High School    83.369193  83.706897  84.288089  84.013699
# Hernandez High School  80.866860  80.660147  81.396140  80.857143
# Holden High School     83.677165  83.324561  83.815534  84.698795
# Huang High School      81.290284  81.512386  81.417476  80.305983
# Johnson High School    81.260714  80.773431  80.616027  81.227564
# Pena High School       83.807273  83.612000  84.335938  84.591160
# Rodriguez High School  80.993127  80.629808  80.864811  80.376426
# Shelton High School    84.122642  83.441964  84.373786  82.781671
# Thomas High School     83.728850  84.254157  83.585542  83.831361
# Wilson High School     83.939778  84.021452  83.764608  84.317673
# Wright High School     83.833333  83.812757  84.156322  84.073171

# %%
# create spending bins
bins = [0, 584.999, 614.999, 644.999, 999999]
group_name = ["<$585", "$585 - 614", "$615 - 644", "> $644"]
school_group_df["spending_bins"] = pd.cut(school_group_df["per_student_budget"], bins, labels = group_name)


by_spending = school_group_df("spending_bins")

avg_math = by_spending['math_score'].mean()
avg_read = by_spending['reading_score'].mean()
pass_math = school_group_df[school_group_df['math_score'] >= 70].groupby('spending_bins')['Student ID'].count()/by_spending['Student ID'].count()
pass_read = school_group_df[school_group_df['reading_score'] >= 70].groupby('spending_bins')['Student ID'].count()/by_spending['Student ID'].count()
overall = school_group_df[(school_group_df['reading_score'] >= 70) & (school_group_df['math_score'] >= 70)].groupby('spending_bins')['Student ID'].count()/by_spending['Student ID'].count()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'per_student_budget'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-56-591b9cb59a3e> in <module>
#       2 bins = [0, 584.999, 614.999, 644.999, 999999]
#       3 group_name = ["<$585", "$585 - 614", "$615 - 644", "> $644"]
# ----> 4 school_group_df["spending_bins"] = pd.cut(school_group_df["per_student_budget"], bins, labels = group_name)
#       5
#       6
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2798             if self.columns.nlevels > 1:
#    2799                 return self._getitem_multilevel(key)
# -> 2800             indexer = self.columns.get_loc(key)
#    2801             if is_integer(indexer):
#    2802                 indexer = [indexer]
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'per_student_budget'

# %%
# Size bins
bins = [0, 999, 1999, 99999999999]
group_name = ["Small (<1000)", "Medium (1000-2000)" , "Large (>2000)"]
complete_data_df["size_bins"] = pd.cut(complete_data_df["size"], bins, labels = group_name)

#group by spending
by_size = complete_data_df.groupby("size_bins")

avg_math = by_size["math_score"].mean()
avg_read = by_size["reading_score"].mean()
pass_math = complete_data_df[complete_data_df["math_score"] >= 70].groupby("size_bins")["Student ID"].count()/by_size["Student ID"].count()
pass_read = complete_data_df[complete_data_df["reading_score"] >= 70].groupby("size_bins")["Student ID"].count()/by_size["Student ID"].count()
overall = complete_data_df[(complete_data_df["reading_score"] >= 70) & (complete_data_df["math_score"] >= 70)].groupby("size_bins")["Student ID"].count()/by_size["Student ID"].count()
by_size = complete_data_df.groupby(["size_bins"], as_index=False).mean()
by_size
# Out:
#             size_bins  School ID         size        budget    Student ID  \
# 0       Small (<1000)   8.692585   797.532757  4.820220e+05  23541.000000
# 1  Medium (1000-2000)   7.208636  1715.739732  1.033931e+06  19993.408472
# 2       Large (>2000)   6.829659  3924.352268  2.510395e+06  19277.575754
#
#    reading_score  math_score
# 0      83.974082   83.828654
# 1      83.867989   83.372682
# 2      81.198674   77.477597

# %%
#Type of School
by_type = complete_data_df.groupby("type")

#calculations 
avg_math = by_type["math_score"].mean()
avg_read = by_type["reading_score"].mean()
pass_math = complete_data_df[complete_data_df["math_score"] >= 70].groupby("type")["Student ID"].count()/by_type["Student ID"].count()
pass_read = complete_data_df[complete_data_df["reading_score"] >= 70].groupby("type")["Student ID"].count()/by_type["Student ID"].count()
overall = complete_data_df[(complete_data_df["reading_score"] >= 70) & (complete_data_df["math_score"] >= 70)].groupby("type")["Student ID"].count()/by_type["Student ID"].count()
by_type = complete_data_df.groupby(["type"], as_index=False).mean()
by_type
# Out:
#        type  School ID         size        budget    Student ID  \
# 0   Charter   6.964163  1717.352468  1.024543e+06  19438.475398
# 1  District   6.984505  4063.261195  2.611175e+06  19650.507711
#
#    reading_score  math_score
# 0      83.902821   83.406183
# 1      80.962485   76.987026
